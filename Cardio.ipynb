# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Foyjul-Islam-Raju/Cardiovascular-Disease-Prediction/master/dataset.csv', sep = ';')

# %%
df.head(10)
# Out:
#    id    age  gender  height  weight  ...  gluc  smoke  alco  active  cardio
# 0   0  18393       2     168    62.0  ...     1      0     0       1       0
# 1   1  20228       1     156    85.0  ...     1      0     0       1       1
# 2   2  18857       1     165    64.0  ...     1      0     0       0       1
# 3   3  17623       2     169    82.0  ...     1      0     0       1       1
# 4   4  17474       1     156    56.0  ...     1      0     0       0       0
# 5   8  21914       1     151    67.0  ...     2      0     0       0       0
# 6   9  22113       1     157    93.0  ...     1      0     0       1       0
# 7  12  22584       2     178    95.0  ...     3      0     0       1       1
# 8  13  17668       1     158    71.0  ...     1      0     0       1       0
# 9  14  19834       1     164    68.0  ...     1      0     0       0       0
#
# [10 rows x 13 columns]

# %%
df.shape
# Out:
# (70000, 13)

# %%
df['age'] = (df['age']/365).round(0)

# %%
df
# Out:
#           id   age  gender  height  weight  ...  gluc  smoke  alco  active  cardio
# 0          0  50.0       2     168    62.0  ...     1      0     0       1       0
# 1          1  55.0       1     156    85.0  ...     1      0     0       1       1
# 2          2  52.0       1     165    64.0  ...     1      0     0       0       1
# 3          3  48.0       2     169    82.0  ...     1      0     0       1       1
# 4          4  48.0       1     156    56.0  ...     1      0     0       0       0
# ...      ...   ...     ...     ...     ...  ...   ...    ...   ...     ...     ...
# 69995  99993  53.0       2     168    76.0  ...     1      1     0       1       0
# 69996  99995  62.0       1     158   126.0  ...     2      0     0       1       1
# 69997  99996  52.0       2     183   105.0  ...     1      0     1       0       1
# 69998  99998  61.0       1     163    72.0  ...     2      0     0       0       1
# ...

# %%
df.drop('id',axis=1)
# Out:
#         age  gender  height  weight  ap_hi  ...  gluc  smoke  alco  active  cardio
# 0      50.0       2     168    62.0    110  ...     1      0     0       1       0
# 1      55.0       1     156    85.0    140  ...     1      0     0       1       1
# 2      52.0       1     165    64.0    130  ...     1      0     0       0       1
# 3      48.0       2     169    82.0    150  ...     1      0     0       1       1
# 4      48.0       1     156    56.0    100  ...     1      0     0       0       0
# ...     ...     ...     ...     ...    ...  ...   ...    ...   ...     ...     ...
# 69995  53.0       2     168    76.0    120  ...     1      1     0       1       0
# 69996  62.0       1     158   126.0    140  ...     2      0     0       1       1
# 69997  52.0       2     183   105.0    180  ...     1      0     1       0       1
# 69998  61.0       1     163    72.0    135  ...     2      0     0       0       1
# ...

# %%
df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
sb.countplot(df['cardio'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.dtypes
# Out:
# id               int64
# age            float64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
sb.countplot(x='gender', hue='cardio', data=df, palette='Greens', edgecolor=sb.color_palette('dark', n_colors=4))

# %%
df.describe()
# Out:
#                  id           age  ...        active        cardio
# count  70000.000000  70000.000000  ...  70000.000000  70000.000000
# mean   49972.419900     53.338686  ...      0.803729      0.499700
# std    28851.302323      6.765294  ...      0.397179      0.500003
# min        0.000000     30.000000  ...      0.000000      0.000000
# 25%    25006.750000     48.000000  ...      1.000000      0.000000
# 50%    50001.500000     54.000000  ...      1.000000      0.000000
# 75%    74889.250000     58.000000  ...      1.000000      1.000000
# max    99999.000000     65.000000  ...      1.000000      1.000000
#
# [8 rows x 13 columns]

# %%
df.drop('id',axis=1)
# Out:
#         age  gender  height  weight  ap_hi  ...  gluc  smoke  alco  active  cardio
# 0      50.0       2     168    62.0    110  ...     1      0     0       1       0
# 1      55.0       1     156    85.0    140  ...     1      0     0       1       1
# 2      52.0       1     165    64.0    130  ...     1      0     0       0       1
# 3      48.0       2     169    82.0    150  ...     1      0     0       1       1
# 4      48.0       1     156    56.0    100  ...     1      0     0       0       0
# ...     ...     ...     ...     ...    ...  ...   ...    ...   ...     ...     ...
# 69995  53.0       2     168    76.0    120  ...     1      1     0       1       0
# 69996  62.0       1     158   126.0    140  ...     2      0     0       1       1
# 69997  52.0       2     183   105.0    180  ...     1      0     1       0       1
# 69998  61.0       1     163    72.0    135  ...     2      0     0       0       1
# ...

# %%
df.corr()
# Out:
#                    id       age    gender  ...      alco    active    cardio
# id           1.000000  0.003050  0.003502  ...  0.001210  0.003755  0.003799
# age          0.003050  1.000000 -0.023017  ... -0.029918 -0.009819  0.237749
# gender       0.003502 -0.023017  1.000000  ...  0.170966  0.005866  0.008109
# height      -0.003038 -0.081456  0.499033  ...  0.094419 -0.006570 -0.010821
# weight      -0.001830  0.053661  0.155406  ...  0.067113 -0.016867  0.181660
# ap_hi        0.003356  0.020793  0.006005  ...  0.001408 -0.000033  0.054475
# ap_lo       -0.002529  0.017754  0.015254  ...  0.010601  0.004780  0.065719
# cholesterol  0.006106  0.154386 -0.035821  ...  0.035760  0.009911  0.221147
# gluc         0.002467  0.098596 -0.020491  ...  0.011246 -0.006770  0.089307
# smoke       -0.003699 -0.047884  0.338135  ...  0.340094  0.025858 -0.015486
# alco         0.001210 -0.029918  0.170966  ...  1.000000  0.025476 -0.007330
# ...

# %%
df.drop('id',axis=1)
# Out:
#         age  gender  height  weight  ap_hi  ...  gluc  smoke  alco  active  cardio
# 0      50.0       2     168    62.0    110  ...     1      0     0       1       0
# 1      55.0       1     156    85.0    140  ...     1      0     0       1       1
# 2      52.0       1     165    64.0    130  ...     1      0     0       0       1
# 3      48.0       2     169    82.0    150  ...     1      0     0       1       1
# 4      48.0       1     156    56.0    100  ...     1      0     0       0       0
# ...     ...     ...     ...     ...    ...  ...   ...    ...   ...     ...     ...
# 69995  53.0       2     168    76.0    120  ...     1      1     0       1       0
# 69996  62.0       1     158   126.0    140  ...     2      0     0       1       1
# 69997  52.0       2     183   105.0    180  ...     1      0     1       0       1
# 69998  61.0       1     163    72.0    135  ...     2      0     0       0       1
# ...

# %%
x = df.iloc[:, :-1]

# %%
y = df.iloc[:, 12]

# %%
x.drop('id',axis=1)
# Out:
#         age  gender  height  weight  ...  gluc  smoke  alco  active
# 0      50.0       2     168    62.0  ...     1      0     0       1
# 1      55.0       1     156    85.0  ...     1      0     0       1
# 2      52.0       1     165    64.0  ...     1      0     0       0
# 3      48.0       2     169    82.0  ...     1      0     0       1
# 4      48.0       1     156    56.0  ...     1      0     0       0
# ...     ...     ...     ...     ...  ...   ...    ...   ...     ...
# 69995  53.0       2     168    76.0  ...     1      1     0       1
# 69996  62.0       1     158   126.0  ...     2      0     0       1
# 69997  52.0       2     183   105.0  ...     1      0     1       0
# 69998  61.0       1     163    72.0  ...     2      0     0       0
# 69999  56.0       1     170    72.0  ...     1      0     0       1
#
# [70000 rows x 11 columns]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split (x, y, test_size = 0.30, random_state=1)

# %%
xtrain
# Out:
#           id   age  gender  height  ...  gluc  smoke  alco  active
# 23561  33670  44.0       2     169  ...     1      1     0       1
# 34858  49789  40.0       1     158  ...     1      0     0       1
# 54953  78398  56.0       1     164  ...     1      0     0       1
# 59230  84572  46.0       1     153  ...     1      0     0       1
# 1730    2449  58.0       1     159  ...     1      0     0       1
# ...      ...   ...     ...     ...  ...   ...    ...   ...     ...
# 49100  70099  58.0       2     175  ...     1      0     0       1
# 20609  29410  52.0       1     164  ...     1      0     0       0
# 21440  30634  49.0       2     178  ...     1      0     0       1
# 50057  71447  60.0       1     169  ...     1      0     0       0
# 5192    7386  57.0       1     174  ...     2      0     0       1
#
# [49000 rows x 12 columns]

# %%
ytrain
# Out:
# 23561    0
# 34858    1
# 54953    0
# 59230    0
# 1730     1
#         ..
# 49100    1
# 20609    0
# 21440    0
# 50057    1
# 5192     1
# Name: cardio, Length: 49000, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
rfcl = RandomForestClassifier()

rfcl.fit(xtrain, ytrain)
rfcl.score(xtest, ytest)
# Out:
# 0.7207619047619047

# %%
y_test_forest = rfcl.predict(xtest)
y_train_forest = rfcl.predict(xtrain)

# %%
from sklearn.metrics import accuracy_score

# %%
#computing the accuracy of the model performance
acc_train_forest = accuracy_score(ytrain,y_train_forest)
acc_test_forest = accuracy_score(ytest,y_test_forest)

print("Random forest: Accuracy on training Data: {:.3f}".format(acc_train_forest))
print("Random forest: Accuracy on test Data: {:.3f}".format(acc_test_forest))
# Out:
# Random forest: Accuracy on training Data: 1.000
# Random forest: Accuracy on test Data: 0.721

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(xtrain, ytrain)
tree.score(xtest, ytest)
# Out:
# 0.6256666666666667

# %%
y_test_tree = tree.predict(xtest)
y_train_tree = tree.predict(xtrain)

# %%
#computing the accuracy of the model performance
acc_train_tree = accuracy_score(ytrain,y_train_tree)
acc_test_tree = accuracy_score(ytest,y_test_tree)

print("Random forest: Accuracy on training Data: {:.3f}".format(acc_train_tree))
print("Random forest: Accuracy on test Data: {:.3f}".format(acc_test_tree))
# Out:
# Random forest: Accuracy on training Data: 1.000
# Random forest: Accuracy on test Data: 0.626
